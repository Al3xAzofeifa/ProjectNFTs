-- %% [markdown]
-- # [ProjectNFTs]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ProjectNFTs]    Script Date: 17/04/2024 08:48:15 p. m. ******/
CREATE DATABASE [ProjectNFTs]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ProjectNFTDatos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ProjectNFTDatos.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ProjectNFTDatos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\ProjectNFTDatos_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [ProjectNFTs] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ProjectNFTs].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ProjectNFTs] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ProjectNFTs] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ProjectNFTs] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ProjectNFTs] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ProjectNFTs] SET ARITHABORT OFF 
GO
ALTER DATABASE [ProjectNFTs] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ProjectNFTs] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ProjectNFTs] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ProjectNFTs] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ProjectNFTs] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ProjectNFTs] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ProjectNFTs] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ProjectNFTs] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ProjectNFTs] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ProjectNFTs] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ProjectNFTs] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ProjectNFTs] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ProjectNFTs] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ProjectNFTs] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ProjectNFTs] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ProjectNFTs] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ProjectNFTs] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ProjectNFTs] SET RECOVERY FULL 
GO
ALTER DATABASE [ProjectNFTs] SET  MULTI_USER 
GO
ALTER DATABASE [ProjectNFTs] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ProjectNFTs] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ProjectNFTs] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ProjectNFTs] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ProjectNFTs] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ProjectNFTs] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ProjectNFTs', N'ON'
GO
ALTER DATABASE [ProjectNFTs] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[ReceiptNumber]

-- %%
USE [ProjectNFTs]
GO

-- %%
USE [ProjectNFTs]
GO
/****** Object:  Sequence [dbo].[ReceiptNumber]    Script Date: 17/04/2024 08:48:15 p. m. ******/
CREATE SEQUENCE [dbo].[ReceiptNumber] 
 AS [bigint]
 START WITH 1
 INCREMENT BY 1
 MINVALUE -9223372036854775808
 MAXVALUE 9223372036854775807
 CACHE  127 
GO

-- %% [markdown]
-- # [dbo].[Cliente]

-- %%
/****** Object:  Table [dbo].[Cliente]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente](
	[IdCriptoWallet] [varchar](50) NULL,
	[Nombre] [varchar](100) NULL,
	[Apellido1] [varchar](100) NULL,
	[Apellido2] [varchar](100) NOT NULL,
	[Email] [varchar](100) NULL,
	[Sexo] [char](1) NULL,
	[FechaDeNacimiento] [datetime] NULL,
	[IdPais] [int] NULL,
	[IdCliente] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK__Cliente__D59466429CACD694] PRIMARY KEY CLUSTERED 
(
	[IdCliente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetalleFactura]

-- %%
/****** Object:  Table [dbo].[DetalleFactura]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleFactura](
	[Cantidad] [int] NULL,
	[Precio] [numeric](18, 2) NULL,
	[IdFactura] [int] NOT NULL,
	[IdDetalle] [int] NOT NULL,
	[IdNFT] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK__Detalle___E43646A5F28235CF] PRIMARY KEY CLUSTERED 
(
	[IdFactura] ASC,
	[IdDetalle] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EncabezadoFactura]

-- %%
/****** Object:  Table [dbo].[EncabezadoFactura]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EncabezadoFactura](
	[IdTarjeta] [int] NULL,
	[EstadoFactura] [int] NULL,
	[FechaFacturacion] [datetime] NULL,
	[NumeroTarjeta] [varchar](20) NULL,
	[Total] [numeric](18, 2) NULL,
	[IdFactura] [int] NOT NULL,
	[IdCliente] [uniqueidentifier] NULL,
 CONSTRAINT [PK__Encabeza__50E7BAF1FB18A0B6] PRIMARY KEY CLUSTERED 
(
	[IdFactura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NFT]

-- %%
/****** Object:  Table [dbo].[NFT]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NFT](
	[Nombre] [varchar](100) NULL,
	[Autor] [varchar](100) NULL,
	[Valor] [numeric](18, 2) NULL,
	[CantidadInventario] [int] NULL,
	[Imagen] [varbinary](max) NOT NULL,
	[Id] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK__NFT__3214EC079F982CA3] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pais]

-- %%
/****** Object:  Table [dbo].[Pais]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pais](
	[IdPais] [int] NOT NULL,
	[Descripcion] [varchar](100) NULL,
 CONSTRAINT [PK__Pais__FC850A7B2B030A20] PRIMARY KEY CLUSTERED 
(
	[IdPais] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Purchase]

-- %%
/****** Object:  Table [dbo].[Purchase]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Purchase](
	[Purchase_ID] [int] IDENTITY(1,1) NOT NULL,
	[Date] [datetime] NOT NULL,
	[ID_NFT] [uniqueidentifier] NOT NULL,
	[Customer_ID] [uniqueidentifier] NOT NULL,
	[Status] [bit] NOT NULL,
 CONSTRAINT [PK_Purchase] PRIMARY KEY CLUSTERED 
(
	[Purchase_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RolUsuario]

-- %%
/****** Object:  Table [dbo].[RolUsuario]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RolUsuario](
	[Id] [int] NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK__RolUsuar__3214EC07DD907290] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tarjeta]

-- %%
/****** Object:  Table [dbo].[Tarjeta]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tarjeta](
	[Id] [int] NOT NULL,
	[Descripcion] [varchar](50) NULL,
	[Estado] [bit] NULL,
 CONSTRAINT [PK__Tarjeta__3214EC07675DC6A0] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 17/04/2024 08:48:15 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[Login] [varchar](20) NOT NULL,
	[IdRol] [int] NULL,
	[Password] [varchar](100) NULL,
	[Nombre] [varchar](50) NULL,
	[Apellido] [varchar](50) NULL,
	[Estado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Login] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Pais_Cliente]

-- %%
ALTER TABLE [dbo].[Cliente]  WITH CHECK ADD  CONSTRAINT [FK_Pais_Cliente] FOREIGN KEY([IdPais])
REFERENCES [dbo].[Pais] ([IdPais])
GO
ALTER TABLE [dbo].[Cliente] CHECK CONSTRAINT [FK_Pais_Cliente]
GO

-- %% [markdown]
-- # [FK_DetalleFactura_EncabezadoFactura]

-- %%
ALTER TABLE [dbo].[DetalleFactura]  WITH CHECK ADD  CONSTRAINT [FK_DetalleFactura_EncabezadoFactura] FOREIGN KEY([IdFactura])
REFERENCES [dbo].[EncabezadoFactura] ([IdFactura])
GO
ALTER TABLE [dbo].[DetalleFactura] CHECK CONSTRAINT [FK_DetalleFactura_EncabezadoFactura]
GO

-- %% [markdown]
-- # [FK_DetalleFactura_NFT1]

-- %%
ALTER TABLE [dbo].[DetalleFactura]  WITH CHECK ADD  CONSTRAINT [FK_DetalleFactura_NFT1] FOREIGN KEY([IdNFT])
REFERENCES [dbo].[NFT] ([Id])
GO
ALTER TABLE [dbo].[DetalleFactura] CHECK CONSTRAINT [FK_DetalleFactura_NFT1]
GO

-- %% [markdown]
-- # [FK_EncabezadoFactura_Cliente1]

-- %%
ALTER TABLE [dbo].[EncabezadoFactura]  WITH CHECK ADD  CONSTRAINT [FK_EncabezadoFactura_Cliente1] FOREIGN KEY([IdCliente])
REFERENCES [dbo].[Cliente] ([IdCliente])
GO
ALTER TABLE [dbo].[EncabezadoFactura] CHECK CONSTRAINT [FK_EncabezadoFactura_Cliente1]
GO

-- %% [markdown]
-- # [FK_Tarjeta_Encabezado_Factura]

-- %%
ALTER TABLE [dbo].[EncabezadoFactura]  WITH CHECK ADD  CONSTRAINT [FK_Tarjeta_Encabezado_Factura] FOREIGN KEY([IdTarjeta])
REFERENCES [dbo].[Tarjeta] ([Id])
GO
ALTER TABLE [dbo].[EncabezadoFactura] CHECK CONSTRAINT [FK_Tarjeta_Encabezado_Factura]
GO

-- %% [markdown]
-- # [FK_Login_Rol]

-- %%
ALTER TABLE [dbo].[Usuario]  WITH CHECK ADD  CONSTRAINT [FK_Login_Rol] FOREIGN KEY([IdRol])
REFERENCES [dbo].[RolUsuario] ([Id])
GO
ALTER TABLE [dbo].[Usuario] CHECK CONSTRAINT [FK_Login_Rol]
GO

-- %% [markdown]
-- # [ProjectNFTs]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ProjectNFTs] SET  READ_WRITE 
GO
